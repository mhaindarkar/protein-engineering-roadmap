# %% [markdown]
# # 01 Structure Introduction
#
# ## Goal
# Understand the protein structure and build a residue-level representation.
#
# ## Steps
# - Load PDB
# - Extract sequence
# - Build residue table
# - Add structural features
# - Add mutation prioritization
#
# ## Notes
# This notebook is the v0 foundation notebook for the whole project.
# Use it for structure understanding, feature engineering, and interpretable residue-level analysis.

# %%
from pathlib import Path
from Bio.PDB import PDBParser

pdb_path = Path("../data/raw/pdb/1LYZ.pdb")

parser = PDBParser(QUIET=True)
structure = parser.get_structure("1LYZ", pdb_path)

print("Loaded structure:", structure)
print("Using file:", pdb_path)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 from pathlib import Path
# ----> 2 from Bio.PDB import PDBParser
#       4 pdb_path = Path("../data/raw/pdb/1LYZ.pdb")
#       6 parser = PDBParser(QUIET=True)
#
# ModuleNotFoundError: No module named 'Bio'

# %%
# Continue here with your existing v0 code:
# - sequence extraction
# - residue table
# - coordinates
# - environment labels
# - ss_simple
# - mutation priority
# - chemistry classes
