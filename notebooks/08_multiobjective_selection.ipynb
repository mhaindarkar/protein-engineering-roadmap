# %% [markdown]
# # 08 Multi-objective Selection
#
# ## Goal
# Combine multiple metrics into final ranking.
#
# ## Purpose
# - integrate confidence, mutation burden, and future scores
# - move from single-threshold filtering to tradeoff-aware selection

# %%
# Example weighted score
combined_df["score"] = (
    combined_df["plddt"] * 0.6 +
    combined_df["ptm"] * 0.4
)

combined_df.sort_values("score", ascending=False).head()

# %%
# Future extension:
# include mutation count, solubility proxy, stability score, embedding score
