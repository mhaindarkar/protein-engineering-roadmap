# %% [markdown]
# # 10 Platform Demo
#
# ## Goal
# Demonstrate the full pipeline from structure to final candidates.
#
# ## Purpose
# - summarize the project as a system
# - show modular execution logic
# - support presentation and portfolio demonstration
#
# ## Version context
# This notebook becomes active in v14.

# %%
print("Full pipeline demo combining all stages will be added here.")

# %%
# Future sections:
# - load target config
# - run preparation
# - run design
# - run validation
# - rank candidates
# - generate summary report
